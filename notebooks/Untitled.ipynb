# %%
# Tester depuis Jupyter
docker exec -it taasim-jupyter python -c "
import requests
url = 'http://minio:9000/raw/porto-trips/train.csv'
r = requests.get(url, auth=('taasim', 'taasim123'))
print(f'Status: {r.status_code}')
print(f'Headers: {r.headers}')
"
# Out:
#   Cell In[1], line 2
#     docker exec -it taasim-jupyter python -c "
#                                              ^
# SyntaxError: unterminated string literal (detected at line 2)
